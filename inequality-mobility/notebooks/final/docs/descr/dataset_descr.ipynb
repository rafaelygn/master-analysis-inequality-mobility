# %%
! pwd
# Out:
# /home/yoshraf/projects/master-analysis-inequality-mobility/inequality-mobility/notebooks/final/docs/descr

# %%
# %reload_kedro
# Out:
# 2025-09-13 23:16:22,693 - kedro.framework.session.store - INFO - `read()` not implemented for `BaseSessionStore`. Assuming empty store.
# 2025-09-13 23:16:22,737 - root - INFO - ** Kedro project Inequality Mobility
# 2025-09-13 23:16:22,739 - root - INFO - Defined global variable `context`, `session` and `catalog`
# 2025-09-13 23:16:22,749 - root - INFO - Registered line magic `run_viz`

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
X_train = catalog.load("X_train_dc")
X_test = catalog.load("X_test_dc")
y_train = catalog.load("y_train_dc")
y_test = catalog.load("y_test_dc")
# Out:
# 2025-09-13 23:16:22,826 - kedro.io.data_catalog - INFO - Loading data from `X_train_dc` (ParquetDataSet)...
# 2025-09-13 23:16:22,921 - kedro.io.data_catalog - INFO - Loading data from `X_test_dc` (ParquetDataSet)...
# 2025-09-13 23:16:22,948 - kedro.io.data_catalog - INFO - Loading data from `y_train_dc` (ParquetDataSet)...
# 2025-09-13 23:16:22,977 - kedro.io.data_catalog - INFO - Loading data from `y_test_dc` (ParquetDataSet)...

# %%
X_test
# Out:
#                                                                                                             idade_em_anos  \
# identifica_pessoa zona_do_domicilio data_da_entrevista coordenada_x_do_domicilio coordenada_y_do_domicilio
# 3.130037e+10      313.0             2023-09-23         320665.0                  7382102.0                           10.0
# 1.810003e+10      181.0             2023-12-02         348497.0                  7400590.0                           22.0
# 1.980000e+10      198.0             2023-08-15         353356.0                  7401072.0                           29.0
# 1.900140e+10      190.0             2023-10-22         350802.0                  7395352.0                           16.0
# 1.250003e+10      125.0             2023-11-20         326440.0                  7403326.0                           60.0
# ...                                                                                                                   ...
# ...

# %%
X = pd.concat([X_train, X_test])
y = pd.concat([y_train, y_test])
X['modo_principal_da_viagem'] = y['modo_principal_da_viagem']
dataset = X.copy()

# %%
(dataset.reset_index()['coordenada_x_do_domicilio'] + dataset.reset_index()['coordenada_y_do_domicilio']).nunique()
# Out:
# 12286

# %%
dataset.reset_index()['identifica_pessoa'].nunique()
# Out:
# 32896

# %%
dataset.shape[0]
# Out:
# 76017

# %%
dataset['modo_principal_da_viagem'].value_counts(normalize=True)*100
# Out:
# Automóvel             32.299354
# A pé                  26.225713
# Ônibus                16.413434
# Metrô/Trem+Ônibus      6.199929
# Metrô/Trem             4.898904
# Taxi/Taxi App          4.731836
# Transporte escolar     4.481892
# Motocicleta            2.574424
# Outros                 1.286554
# Bicicleta              0.887959
# Name: modo_principal_da_viagem, dtype: float64

# %%
X.describe().loc[['min', 'max', 'mean', 'std']].T
# Out:
# /home/yoshraf/projects/master-analysis-inequality-mobility/venv/lib/python3.8/site-packages/pandas/core/nanops.py:1723: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   return np.percentile(values, q, axis=1, interpolation=interpolation)
#                                                  min            max  \
# idade_em_anos                               1.000000     102.000000
# total_de_viagens_da_pessoa                  1.000000      16.000000
# hora_de_saida                               0.000000      23.983333
# loc_origem_dist_metro                       2.575264   63896.260639
# loc_origem_dist_trem                        1.404764   52665.278320
# loc_origem_dist_term                       13.669797   57720.076988
# ...

# %%
dataset.filter(regex='motivo', axis=1).describe().loc['mean'].sort_values(ascending=False) *100
# Out:
# /home/yoshraf/projects/master-analysis-inequality-mobility/venv/lib/python3.8/site-packages/pandas/core/nanops.py:1723: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   return np.percentile(values, q, axis=1, interpolation=interpolation)
# motivo_no_destino_Residência                 47.389400
# motivo_no_destino_Trabalho Serviços          17.744715
# motivo_no_destino_Escola/Educação            15.430759
# motivo_no_destino_Trabalho Comércio           4.710788
# motivo_no_destino_Recreação/Visitas/Lazer     2.945394
# motivo_no_destino_Médico/Dentista/Saúde       2.873042
# motivo_no_destino_Compras                     2.842785
# motivo_no_destino_Assuntos Pessoais           2.723075
# motivo_no_destino_Trabalho Indústria          2.217925
# ...
